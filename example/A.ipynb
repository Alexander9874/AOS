# %% [markdown]
# hello

# %%
DIRECTORY="./A"

cd "$DIRECTORY" || exit

rm -rf *.out

for file in *.c; do
    # Проверяем, существует ли файл
    if [[ -f "$file" ]]; then
        filename="${file%.c}"
        gcc "$file" -o "$filename.out"
    fi
done
