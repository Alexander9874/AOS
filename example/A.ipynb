# %% [markdown]
# hello

# %%
DIRECTORY="./A"

cd "$DIRECTORY" || exit

rm -rf *.out

for file in *.c; do
    # Проверяем, существует ли файл
    if [[ -f "$file" ]]; then
        filename="${file%.c}"
        gcc "$file" -o "$filename.out"
    fi
done
# Out:
# a01.c: In function ‘main’:
# a01.c:13:11: warning: implicit declaration of function ‘write’; did you mean ‘fwrite’? [-Wimplicit-function-declaration]
#    13 |         i=write(l, "test1\n", 6);
#       |           ^~~~~
#       |           fwrite
# a01.c:18:9: warning: implicit declaration of function ‘close’; did you mean ‘pclose’? [-Wimplicit-function-declaration]
#    18 |         close (l);
#       |         ^~~~~
#       |         pclose
# a02.c: In function ‘main’:
# a02.c:10:42: warning: unused parameter ‘envp’ [-Wunused-parameter]
#    10 | int main(int argc, char * argv[], char * envp[]) {
#       |                                   ~~~~~~~^~~~~~
# a03.c: In function ‘main’:
# a03.c:11:14: warning: unused parameter ‘argc’ [-Wunused-parameter]
#    11 | int main(int argc, char * argv[], char * envp[]){
#       |          ~~~~^~~~
# a03.c:11:27: warning: unused parameter ‘argv’ [-Wunused-parameter]
#    11 | int main(int argc, char * argv[], char * envp[]){
# ...
